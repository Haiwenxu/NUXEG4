# %%
import numpy as np
import uproot
import matplotlib.pyplot as plt

# %%
my_root = uproot.open("./Data/LXe_ntuple.root")
my_root["NUXE"].keys()
# Out:
# ['Event_Energy',
#  'Event_X',
#  'Event_Y',
#  'Event_Z',
#  'Hit_Time',
#  'Hit_X',
#  'Hit_Y',
#  'Hit_Z']

# %%
Event_Energy = my_root["NUXE/Event_Energy"].array(library="np")
Event_X = my_root["NUXE/Event_X"].array(library="np")
Event_Y = my_root["NUXE/Event_Y"].array(library="np")
Event_Z = my_root["NUXE/Event_Z"].array(library="np")
time_vec = my_root["NUXE/Hit_Time"].array(library="np")
x_vec = my_root["NUXE/Hit_X"].array(library="np")
y_vec = my_root["NUXE/Hit_Y"].array(library="np")
z_vec = my_root["NUXE/Hit_Z"].array(library="np")

# %%
plt.figure(figsize=(8,8))
plt.hist2d(np.hstack(y_vec),np.hstack(x_vec),200)
plt.show()

# %%
np.hstack(time_vec)
# Out:
# (8016,)
